# %% [markdown]
# ### Práctica - Análisis de datos del Titanic
#
# Lo típico es que se use un archivo con los datos del Titanic para practicar (risas)

# %%
# Importación de librería

import pandas as pd
import matplotlib.pyplot as plt

# %%
# importación de archivo

titanic = pd.read_excel("titanic3.xls")
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# La forma del dataset

titanic.shape
# Out:
# (1309, 14)

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
# Creación de dataset personalizado

titanic2 = titanic[["name", "sex", "age", "survived", "pclass"]]
titanic2.head()
# Out:
#                                               name     sex      age  survived  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000         1
# 1                   Allison, Master. Hudson Trevor    male   0.9167         1
# 2                     Allison, Miss. Helen Loraine  female   2.0000         0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000         0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000         0
#
#    pclass
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Sobrevivientes

sobrev = titanic2[titanic2["survived"] == 1]
sobrev.head()
# Out:
#                                             name     sex      age  survived  \
# 0                  Allen, Miss. Elisabeth Walton  female  29.0000         1
# 1                 Allison, Master. Hudson Trevor    male   0.9167         1
# 5                            Anderson, Mr. Harry    male  48.0000         1
# 6              Andrews, Miss. Kornelia Theodosia  female  63.0000         1
# 8  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0000         1
#
#    pclass
# 0       1
# 1       1
# 5       1
# 6       1
# 8       1

# %%
# Estadísticas generales de los sobrevivientes

sobrev.describe()
# Out:
#               age  survived      pclass
# count  427.000000     500.0  500.000000
# mean    28.918228       1.0    1.962000
# std     15.061481       0.0    0.872972
# min      0.166700       1.0    1.000000
# 25%     20.000000       1.0    1.000000
# 50%     28.000000       1.0    2.000000
# 75%     38.000000       1.0    3.000000
# max     80.000000       1.0    3.000000

# %%
# Conversión numérica de los sobrevivientes por sexo

sobrev_sex = pd.get_dummies(sobrev["sex"], prefix = "sex")

# %%
# Reemplazar la columna sex por las columnas recién creadas. Eliminar la columna "sex"

sobrev = sobrev.drop("sex", axis = 1)

# %%
# Agregar las columnas de hombre y mujer al dataset

sobrev = pd.concat([sobrev, sobrev_sex], axis = 1, join = "inner")

# %%
# Sobrevivientes de primera clase

sobrev[sobrev["pclass"] == 1].head()
# Out:
#                                             name      age  survived  pclass  \
# 0                  Allen, Miss. Elisabeth Walton  29.0000         1       1
# 1                 Allison, Master. Hudson Trevor   0.9167         1       1
# 5                            Anderson, Mr. Harry  48.0000         1       1
# 6              Andrews, Miss. Kornelia Theodosia  63.0000         1       1
# 8  Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0000         1       1
#
#    sex_female  sex_male
# 0           1         0
# 1           0         1
# 5           0         1
# 6           1         0
# 8           1         0

# %%
# Sobrevivientes hombres

sobrev_m = sobrev[sobrev["sex_male"] == 1]
sobrev_m.shape
# Out:
# (161, 6)

# %%
# Sobrevivientes mujeres

sobrev_f = sobrev[sobrev["sex_female"] == 1]
sobrev_f.shape
# Out:
# (339, 6)

# %%
# Muertos en total

muertos = titanic2[titanic2["survived"] == 0]
muertos.head()
# Out:
#                                               name     sex   age  survived  \
# 2                     Allison, Miss. Helen Loraine  female   2.0         0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0         0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0         0
# 7                           Andrews, Mr. Thomas Jr    male  39.0         0
# 9                          Artagaveytia, Mr. Ramon    male  71.0         0
#
#    pclass
# 2       1
# 3       1
# 4       1
# 7       1
# 9       1

# %%
# Hombres muertos

muertos_m = muertos[muertos["sex"] == "male"]
muertos_m.head()
# Out:
#                                     name   sex   age  survived  pclass
# 3   Allison, Mr. Hudson Joshua Creighton  male  30.0         0       1
# 7                 Andrews, Mr. Thomas Jr  male  39.0         0       1
# 9                Artagaveytia, Mr. Ramon  male  71.0         0       1
# 10                Astor, Col. John Jacob  male  47.0         0       1
# 15                   Baumann, Mr. John D  male   NaN         0       1

# %%
# Mujeres muertas

muertos_f = muertos[muertos["sex"] == "female"]
muertos_f.head()
# Out:
#                                                 name     sex   age  survived  \
# 2                       Allison, Miss. Helen Loraine  female   2.0         0
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0         0
# 105                         Evans, Miss. Edith Corse  female  36.0         0
# 169                       Isham, Miss. Ann Elizabeth  female  50.0         0
# 286           Straus, Mrs. Isidor (Rosalie Ida Blun)  female  63.0         0
#
#      pclass
# 2         1
# 4         1
# 105       1
# 169       1
# 286       1

# %%
# Puesta de datos para gŕafico (pendiente)

muertos_m.shape[0]
# Out:
# 682
